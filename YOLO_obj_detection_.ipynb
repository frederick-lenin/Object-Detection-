# %% [markdown]
# <a href="https://colab.research.google.com/github/frederick-lenin/Object-Detection-/blob/main/YOLO_obj_detection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from os.path import exists, join, basename, splitext

git_repo_url = 'https://github.com/frederick-lenin/pytorch-yolo-v3.git'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # clone and install dependencies
  # !git clone -q $git_repo_url
  #!cd $project_name && pip install -q -r requirement.txt
  
import sys
sys.path.append(project_name)
import time
import matplotlib
import matplotlib.pylab as plt
plt.rcParams["axes.grid"] = False

# %%
#Load the yolo V3 weight file from pjreddie 
if not exists('yolov3.weights'):
  # !wget -q https://pjreddie.com/media/files/yolov3.weights

# %%
#Enter the url of the image that to be predicted

IMAGE_URL = input("")


image_file = basename(IMAGE_URL)
# !wget -q -O $image_file $IMAGE_URL
plt.imshow(matplotlib.image.imread(image_file))
# Out:
# https://images.all-free-download.com/images/graphicwebp/crowd_of_people_205778.webp

# %%
# !cd pytorch-yolo-v3 && python detect.py --weights ../yolov3.weights --images ../$image_file --det ..

plt.figure(figsize=(20, 15))
plt.imshow(matplotlib.image.imread('det_%s' % image_file))
# Out:
# Loading network.....
# Network successfully loaded
# crowd_of_people_205778.webp predicted in  1.314 seconds
# Objects Detected:    person person person person person person person person person person person person person person person person person person
# ----------------------------------------------------------
#
# SUMMARY
# ----------------------------------------------------------
# Task                     : Time Taken (in seconds)
#
# Reading addresses        : 0.000
# Loading batch            : 1.422
# Detection (1 images)     : 1.316
# Output Processing        : 0.000
# Drawing Boxes            : 0.258
# Average time_per_img     : 2.996
# ----------------------------------------------------------
